# %%
from manim import *
# Out:
# Manim Community v0.18.0

# %%
# %%manim -qm FirstExample
#
# class FirstExample(Scene):
#     def construct(self):
#         blue_circle = Circle(color=BLUE, fill_opacity=0.5)
#         green_square = Square(color=GREEN, fill_opacity=0.8)
#         green_square.next_to(blue_circle, RIGHT)
#         self.add(blue_circle, green_square)
# Out:
# [03/07/24 19:29:12] INFO                                                                   ]8;id=342051;file://D:\miniconda3\envs\manim\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=45156;file://D:\miniconda3\envs\manim\lib\site-packages\manim\scene\scene_file_writer.py#735\735]8;;\
#                              File ready at
#                              'D:\program\python\ManimLearn\media\images\ManimLearn\FirstEx
#                              ample_ManimCE_v0.18.0.png'
#                     INFO     Rendered FirstExample                                                     ]8;id=613868;file://D:\miniconda3\envs\manim\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=903172;file://D:\miniconda3\envs\manim\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 0 animations
